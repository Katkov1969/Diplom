# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
users = ('РўР°РЅСЏ', 'РџРµС‚СЏ', 'РЎР»Р°РІР°', 'РљРѕР»СЏ', 'РњРёС€Р°', 'Р›РµРЅР°')
y_pos = np.arange(len(users))
age = [25, 28, 16, 34, 32, 41]

# %%
p2jfig, axs = plt.subplots(2, 1, figsize=(10, 8))

# %%
axs[0].bar(y_pos, age, color='r', align='center', alpha=0.5)
axs[0].set_xticks(y_pos, users)
axs[0].set_ylabel('Р’РѕР·СЂР°СЃС‚')
axs[0].set_title('Р’РµСЂС‚РёРєР°Р»СЊРЅР°СЏ РґРёР°РіСЂР°РјРјР°')
axs[0].grid(True)

# %%
axs[1].barh(y_pos, age, color='g', align='center', alpha=0.5)
axs[1].set_xlabel('Р’РѕР·СЂР°СЃС‚')
axs[1].set_yticks(y_pos, users)
axs[1].set_title('Р“РѕСЂРёР·РѕРЅС‚Р°Р»СЊРЅР°СЏ РґРёР°РіСЂР°РјРјР°')
axs[1].grid(True)
plt.tight_layout()

# %%
plt.show()
