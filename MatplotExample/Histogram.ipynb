# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
#     <br>
# РџРѕСЃС‚СЂРѕРµРЅРёРµ РіРёСЃС‚РѕРіСЂР°РјРјС‹ РЅР° РѕСЃРЅРѕРІРµ РїСЂРµРґРѕСЃС‚Р°РІР»РµРЅРЅС‹С… РґР°РЅРЅС‹С… <br>
# data - СЃРїРёСЃРѕРє С‡РёСЃР»РѕРІС‹С… Р·РЅР°С‡РµРЅРёР№ <br>
# bins - РєРѕР»РёС‡РµСЃС‚РІРѕ Р±РёРЅРѕРІ РЅР° РіРёСЃС‚РѕРіСЂР°РјРјРµ<br>

# %%
def plot_histogram(data, bins):
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=bins, color='c', edgecolor='k')
    plt.title('Р“РёСЃС‚РѕРіСЂР°РјРјР° СЂР°СЃРїСЂРµРґРµР»РµРЅРёСЏ')
    plt.xlabel('Р—РЅР°С‡РµРЅРёРµ')
    plt.ylabel('Р§Р°СЃС‚РѕС‚Р°')
    plt.grid(True)
    plt.show()

    # РІС‹Р·РѕРІ

# %%
data = np.random.normal(loc=0, scale=1, size=1000)
plot_histogram(data, 20)
