# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_boxplot(data, labels):
    """
    РЎС‚СЂРѕРёС‚ РґРёР°РіСЂР°РјРјСѓ СЂР°Р·РјР°С…Р°.
    data: РЎРїРёСЃРѕРє С‡РёСЃР»РѕРІС‹С… Р·РЅР°С‡РµРЅРёР№, СЃРіСЂСѓРїРїРёСЂРѕРІР°РЅРЅС‹С… РїРѕ РєР°С‚РµРіРѕСЂРёСЏРј.
    labels: РњРµС‚РєРё РєР°С‚РµРіРѕСЂРёР№.
    """
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=data)
    plt.xticks(ticks=np.arange(len(labels)), labels=labels)
    plt.title('РЇС‰РёРє СЃ СѓСЃР°РјРё')
    plt.xlabel('РљР°С‚РµРіРѕСЂРёРё')
    plt.ylabel('Р—РЅР°С‡РµРЅРёРµ')
    plt.grid(True)
    plt.show()

# %% [markdown]
#  <br>
# Р“РµРЅРµСЂР°С‚РѕСЂ РЅРѕСЂРј СЂР°СЃРїСЂ. <br>
# loc - С†РµРЅС‚СЂ 0-3, <br>
# scale - СЂР°Р·Р±СЂРѕСЃ <br>

# %%
data = [np.random.normal(loc, 1, 100) for loc in range(4)]
print(data)
labels = ['A', 'B', 'C', 'D']
plot_boxplot(data, labels)
