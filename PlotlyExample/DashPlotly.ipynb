# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

# %% [markdown]
# РЎРѕР·РґР°РЅРёРµ РїСЂРёР»РѕР¶РµРЅРёСЏ Dash

# %%
app = dash.Dash(__name__)

# %% [markdown]
# Р“РµРЅРµСЂР°С†РёСЏ РґР°РЅРЅС‹С…

# %%
df = pd.DataFrame({
    "Р¤СЂСѓРєС‚С‹": ["РЇР±Р»РѕРєРё", "РђРїРµР»СЊСЃРёРЅС‹", "Р‘Р°РЅР°РЅС‹", "РЇР±Р»РѕРєРё", "РђРїРµР»СЊСЃРёРЅС‹", "Р‘Р°РЅР°РЅС‹"],
    "РљРѕР»РёС‡РµСЃС‚РІРѕ": [4, 1, 2, 2, 4, 5],
    "Р“РѕСЂРѕРґ": ["РЎС‚Р°РІСЂРѕРїРѕР»СЊ", "РЎС‚Р°РІСЂРѕРїРѕР»СЊ", "РЎС‚Р°РІСЂРѕРїРѕР»СЊ", "РњРѕСЃРєРІР°", "РњРѕСЃРєРІР°", "РњРѕСЃРєРІР°"]
})

# %% [markdown]
# РЎРѕР·РґР°РЅРёРµ РіСЂР°С„РёРєР° СЃ РїРѕРјРѕС‰СЊСЋ Plotly Express

# %%
fig = px.bar(df, x="Р¤СЂСѓРєС‚С‹", y="РљРѕР»РёС‡РµСЃС‚РІРѕ", color="Р“РѕСЂРѕРґ", barmode="group")

# %% [markdown]
# РћРїСЂРµРґРµР»РµРЅРёРµ РјР°РєРµС‚Р° РїСЂРёР»РѕР¶РµРЅРёСЏ

# %%
app.layout = html.Div(children=[
    html.H1(children='Hello Dash!!!'),
    html.Div(children='''Dash: Р¤СЂРµР№РјРІРѕСЂРє РІРµР±-РїСЂРёР»РѕР¶РµРЅРёСЏ РґР»СЏ Python.'''),
    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

# %% [markdown]
# Р—Р°РїСѓСЃРє РїСЂРёР»РѕР¶РµРЅРёСЏ

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
