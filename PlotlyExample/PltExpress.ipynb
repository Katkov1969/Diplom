# %%
import plotly.express as px

# %% [markdown]
# <br>
# РљР»Р°СЃС‚РµСЂРёР·Р°С†РёСЏ РёСЂРёСЃРѕРІ Р¤РёС€РµСЂР°<br>

# %%
df = px.data.iris()
fig = px.scatter(df,
                 x="sepal_width", y="sepal_length",
                 color="species",
                 title="A Plotly Express Figure")
fig.show()
